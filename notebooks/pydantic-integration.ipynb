# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from encomp.tests.test_pydantic import test_model_serialize

test_model_serialize()

# %%
import numpy as np
from pydantic import BaseModel

from encomp.units import Quantity
from encomp.utypes import Mass


class M(BaseModel):
    qty: Quantity[Mass]


m = M(qty=Quantity(np.array([[1, 2, 3], [1, 2, 3]]), "kg"))


json_src = m.model_dump_json()
print(json_src)


M.model_json_schema()
# Out:
# {"qty":{"unit":"kg","value":[[1.0,2.0,3.0],[1.0,2.0,3.0]],"magnitude_type":"np.ndarray:<f8:(2, 3)"}}
# {'properties': {'qty': {'properties': {'unit': {'type': 'string'},
#     'value': {'anyOf': [{'type': 'number'},
#       {'items': {'type': 'number'}, 'type': 'array'},
#       {'type': 'null'}]},
#     'magnitude_type': {'description': "describes how to reconstruct the magnitude, e.g. 'int', 'float', 'list', 'np.ndarray:<dtype>:<shape>', or 'pl.Series:<dtype>'",
#      'type': 'string'}},
#    'required': ['unit', 'value', 'magnitude_type'],
#    'title': 'Quantity[Mass]',
#    'type': 'object'}},
#  'required': ['qty'],
#  'title': 'M',
#  'type': 'object'}
